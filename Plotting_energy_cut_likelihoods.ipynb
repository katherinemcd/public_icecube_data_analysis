# %%
import io, os, sys, types
from IPython import get_ipython
from nbformat import current
from IPython.core.interactiveshell import InteractiveShell
def find_notebook(fullname, path=None):
    """find a notebook, given its fully qualified name and an optional path

    This turns "foo.bar" into "foo/bar.ipynb"
    and tries turning "Foo_Bar" into "Foo Bar" if Foo_Bar
    does not exist.
    """
    name = fullname.rsplit('.', 1)[-1]
    if not path:
        path = ['']
    for d in path:
        nb_path = os.path.join(d, name + ".ipynb")
        if os.path.isfile(nb_path):
            return nb_path
        # let import Notebook_Name find "Notebook Name.ipynb"
        nb_path = nb_path.replace("_", " ")
        if os.path.isfile(nb_path):
            return nb_path


class NotebookLoader(object):
    """Module Loader for Jupyter Notebooks"""
    def __init__(self, path=None):
        self.shell = InteractiveShell.instance()
        self.path = path

    def load_module(self, fullname):
        """import a notebook as a module"""
        path = find_notebook(fullname, self.path)

        print ("importing Jupyter notebook from %s" % path)

        # load the notebook object
        with io.open(path, 'r', encoding='utf-8') as f:
            nb = current.read(f, 'json')


        # create the module and add it to sys.modules
        # if name in sys.modules:
        #    return sys.modules[name]
        mod = types.ModuleType(fullname)
        mod.__file__ = path
        mod.__loader__ = self
        mod.__dict__['get_ipython'] = get_ipython
        sys.modules[fullname] = mod

        # extra work to ensure that magics that would affect the user_ns
        # actually affect the notebook module's ns
        save_user_ns = self.shell.user_ns
        self.shell.user_ns = mod.__dict__

        try:
            for cell in nb.worksheets[0].cells:
                if cell.cell_type == 'code' and cell.language == 'python':
                # transform the input to executable Python
                    code = self.shell.input_transformer_manager.transform_cell(cell.input)
                # run the code in themodule
                    exec(code, mod.__dict__)
        finally:
            self.shell.user_ns = save_user_ns
        return mod


class NotebookFinder(object):
    """Module finder that locates Jupyter Notebooks"""
    def __init__(self):
        self.loaders = {}

    def find_module(self, fullname, path=None):
        nb_path = find_notebook(fullname, path)
        if not nb_path:
            return

        key = path
        if path:
            # lists aren't hashable
            key = os.path.sep.join(path)

        if key not in self.loaders:
            self.loaders[key] = NotebookLoader(path)
        return self.loaders[key]

sys.meta_path.append(NotebookFinder())
# Out:
# /software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/site-packages/nbformat/current.py:19: UserWarning: nbformat.current is deprecated.
#
# - use nbformat for read/write/validate public API
# - use nbformat.vX directly to composing notebooks of a particular version
#
#   """

# %% [markdown]
# This is basically just the normal A05 but with some edits to make the energy cut and for how I saved the data.

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from multiprocessing import Pool
import IceCubeAnalysis3


def main(icecube_file_name, background_file_name, catalog_file_name, source_class_names,
         alpha=2.0, weights_type='dist', n_cpu=10, var_index_cut=None):
    """
    For points in the sky from the 4LAC catalog, the function scans
    over the number of neutrinos in the data from the source class
    and calculates the likelihood. The number of neutrinos associated
    to each source in the source class is determined by a weighting,
    which is described in more detail in the paper. If a statistically
    significant number of tracks in the data are associated with this
    source class, the resulting likelihood will peak above 3sigma.
    Parameters
    ----------
    icecube_file_name : str
        File location of pickled IceCube track data.
    background_file_name : str
        File location of pre-processed background PDF.
    catalog_file_name : str
        File location of pickled 4LAC catalog.
    source_class_names : array_like
        Names of source classes used in calculation.
    alpha : float
        Neutrino energy spectrum integrated with the effective area.
    weights_type : str
        The weighting used for the source class. Options are 'flat' for
        equal weight, 'flux' to weight against the gamma-ray flux, and
        'dist' to weight against the luminosity distance.
    n_cpu : int
        The number of CPUs to use in the parallelization.
        If n_cpu is None, the computation is not parallelized.
    var_index_cut : float
        Removes events that have a variability index greater
        than var_index_cut. If None, no cut is performed.
    Returns
    ----------
    sweep_flux : array
        The array of fluxes of astrophysical neutrinos used
        to calculate the likelihood of the source class
        producing said astrophysical neutrino flux.
    sweep_ts : array
        The cumulative likelihood of the source class producing
        the flux of astrophysical neutrinos.
    sweep_ts_each_source : array
        The likelihood of each individual source producing
        the flux of astrophysical neutrinos.
    """

    if(n_cpu is not None):
        use_parallel = True
    else:
        use_parallel = False
    
    #Creates the interval of enery cuts I want, then loops over them
    interval = np.linspace(0,8000,num=40)
    max_prob = np.zeros(len(interval))
    for i in range(len(interval)):
        sourcesearch_ = IceCubeAnalysis3.SourceSearch(icecube_file_name,interval[i])
        sourcesearch_.load_background(background_file_name)

        # The time used in integration, in seconds
        T = (10.0 * 365.25 * 24.0 * 3600.0)

        # The energy bounds used in integration.
        E1 = 100.0
        E2 = 30.0

        Aeff_filename = "./processed_data/output_icecube_AffIntegrated_%s.npz" % alpha
        class_search = IceCubeAnalysis3.SourceClassSearch(T, E1, E2, alpha, sourcesearch_, Aeff_filename)


        class_search.load_4lac(catalog_file_name, source_class_names, weights_type)

        if(var_index_cut is not None):
            class_search.var_index_cut(var_index_cut)

        print("Number of Sources:\t %i" % class_search.N)
        print("Number of Events:\t %i" % sourcesearch_.N)

        start_time = time.time()

        if(use_parallel):
            args_for_multiprocessing = np.arange(class_search.N)

            pool = Pool(n_cpu)
            parallel_results = pool.map(class_search.source_loop,
                                        args_for_multiprocessing)
            pool.close()

            parallel_results = [list(t) for t in zip(*parallel_results)]

            sweep_ts_each_source = np.stack(parallel_results[1], axis=1)
            sweep_ts = np.sum(parallel_results[1], axis=0)
            sweep_flux = np.sum(parallel_results[0], axis=0)
        else:
            # Calculate the points that we will then loop over
            parameterized_span = class_search.calculate_span()

            sweep_ts = np.zeros(len(parameterized_span))
            sweep_flux = np.zeros(len(parameterized_span))
            sweep_ts_each_source = np.zeros((len(parameterized_span), class_search.N))

            for i_source in range(class_search.N):
                sweep_fluxes_, ts_results_ = class_search.source_loop(i_source)

                sweep_flux += sweep_fluxes_
                sweep_ts += ts_results_
                sweep_ts_each_source[:, i_source] = ts_results_

        end_time = time.time()

        if(use_parallel):
            print("Using parallel, time passed was: \t %f" % (end_time - start_time))
        else:
            print("Using nonparallel, time passed was: \t %f" % (end_time - start_time))

        sweep_flux *= 1000.0  # convert TeV to GeV
        
        #finds the max likelihood of this energy cut and saves it into max_prob
        max_prob[i]=np.max(sweep_ts)
        print(max_prob[i])
        
        
    return sweep_flux, sweep_ts, sweep_ts_each_source, max_prob, interval


if(__name__ == "__main__"):

    catalog_file_name = "./processed_data/fake_4lac_set.npz"
    icecube_file_name = "./processed_data/energy_cut_data.npz"
    background_file_name = "./processed_data/output_icecube_background_MC.npz"

    output_file_preamble = ['nonblazar','blazar']
    cut_type = ['Nocut','non_var']
    blazar = ['BLL', 'bll', 'FSRQ', 'fsrq', 'BCU', 'bcu']
    nonblazar = ['agn','RDG', 'rdg', 'AGN', 'agn', 'NLSY1', 'nlsy1','CSS','css','SSRQ','ssrq','SEY','sey']
    every = ['BLL', 'bll', 'FSRQ', 'fsrq', 'BCU', 'bcu','RDG', 'rdg', 'AGN', 'agn', 'NLSY1', 'nlsy1','CSS','css','SSRQ','ssrq','SEY','sey']
    source_class_names = [every]
    
    #weights_types = ['flat', 'flux', 'dist','inv_flux']
    weights_types = ['flat']
    colors = ['orange', 'green', 'blue','purple']
    labels = ['Flat', r'$\gamma$-Ray', r'1/D$_L^2$',r'1/$\gamma$-ray']
    var_cut_types = [None]

    alphas = [2.5, 2.0]
    linestyles = ['-', '--']

    for i_source_class_names, source_class_name in enumerate(source_class_names):
    
        for i_var_cut_types, var_cut_type in enumerate(var_cut_types):

            plt.figure(figsize=(5, 4))

            for i_alpha, alpha in enumerate(alphas):

                for i_weights_type, weights_type in enumerate(weights_types):
                    sweep_flux, sweep_ts, sweep_ts_each_source, max_prob, interval = main(icecube_file_name=icecube_file_name,
                                                                                         background_file_name=background_file_name,
                                                                                         catalog_file_name=catalog_file_name,
                                                                                         source_class_names=source_class_name,
                                                                                         alpha=alpha,
                                                                                         weights_type=weights_type,
                                                                                         n_cpu=10,
                                                                                         var_index_cut=var_cut_type)

#plots the energy cut vs max likilihood
                plt.scatter(interval, max_prob)
                plt.xlabel("Energy (TeV) cut")
                plt.ylabel("Max $2 \Delta \ln \mathcal{L}$")
                plt.ylim(-7,7)
                plt.show()
# Out:
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 100000
# Using parallel, time passed was: 	 5.200402
# -0.37428041687235236
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 14156
# Using parallel, time passed was: 	 1.718423
# -1.4958867337736592
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 11367
# Using parallel, time passed was: 	 1.612839
# -1.6120239649462746
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 9794
# Using parallel, time passed was: 	 1.554131
# -1.7180769903734472
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 8664
# Using parallel, time passed was: 	 1.528839
# -1.8444115307902393
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 7900
# Using parallel, time passed was: 	 1.483339
# -1.9025870971599943
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 7225
# Using parallel, time passed was: 	 1.466957
# -1.2597429381676193
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 6639
# Using parallel, time passed was: 	 1.463269
# -1.364560794809222
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 6149
# Using parallel, time passed was: 	 1.417928
# -1.0586901702517935
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 5740
# Using parallel, time passed was: 	 1.411740
# -0.5546046192202994
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 5364
# Using parallel, time passed was: 	 1.420056
# -0.33116214584697445
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 5041
# Using parallel, time passed was: 	 1.387393
# 0.3510230350311758
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 4758
# Using parallel, time passed was: 	 1.375654
# 0.12452989629127842
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 4487
# Using parallel, time passed was: 	 1.364896
# -0.003803178862654022
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 4260
# Using parallel, time passed was: 	 1.349435
# -0.014629577647610859
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 4017
# Using parallel, time passed was: 	 1.341545
# 0.5692569953125712
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 3783
# Using parallel, time passed was: 	 1.346110
# 1.0123169993739793
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 3596
# Using parallel, time passed was: 	 1.323315
# 1.3525961415753045
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 3412
# Using parallel, time passed was: 	 1.337106
# 1.302052661732887
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 3215
# Using parallel, time passed was: 	 1.310222
# 0.2281014081363537
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 3033
# Using parallel, time passed was: 	 1.326373
# 0.1342180374012969
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 2871
# Using parallel, time passed was: 	 1.321120
# 0.1194211365659612
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 2713
# Using parallel, time passed was: 	 1.309376
# -0.10830340560460172
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 2538
# Using parallel, time passed was: 	 1.290399
# -1.6444530227654468
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 2399
# Using parallel, time passed was: 	 1.282175
# -0.9221530838481158
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 2257
# Using parallel, time passed was: 	 1.281687
# -0.9971066633274859
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 2115
# Using parallel, time passed was: 	 1.275337
# -1.0246773947369547
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1991
# Using parallel, time passed was: 	 1.274176
# 0.13707719965395881
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1856
# Using parallel, time passed was: 	 1.272798
# 0.3081007278206016
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1736
# Using parallel, time passed was: 	 1.279506
# 0.745750905627574
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1626
# Using parallel, time passed was: 	 1.257889
# 0.9626687828235845
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1513
# Using parallel, time passed was: 	 1.243769
# -0.16251372876331516
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1408
# Using parallel, time passed was: 	 1.233745
# 0.7242845972507439
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1317
# Using parallel, time passed was: 	 1.254736
# 1.5999452257085522
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1223
# Using parallel, time passed was: 	 1.238294
# 0.5789299269567891
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1125
# Using parallel, time passed was: 	 1.257715
# -2.378438965253963
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 1027
# Using parallel, time passed was: 	 1.255263
# -2.839070405097573
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 934
# Using parallel, time passed was: 	 1.242768
# -3.6220757435025916
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 857
# Using parallel, time passed was: 	 1.231083
# -4.296554901185345
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 788
# Using parallel, time passed was: 	 1.297998
# -3.377737550993288
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 100000
# Using parallel, time passed was: 	 5.140172
# -0.27540542391943745
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 14156
# Using parallel, time passed was: 	 1.725761
# -0.9643704001609876
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 11367
# Using parallel, time passed was: 	 1.629016
# -0.9984772159896238
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 9794
# Using parallel, time passed was: 	 1.565744
# -1.0009014190072776
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 8664
# Using parallel, time passed was: 	 1.510502
# -1.149341555310457
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 7900
# Using parallel, time passed was: 	 1.478493
# -1.171190482826205
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 7225
# Using parallel, time passed was: 	 1.456117
# -0.6603862702340848
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 6639
# Using parallel, time passed was: 	 1.446090
# -0.6851760267127247
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 6149
# Using parallel, time passed was: 	 1.427643
# -0.4630004270502468
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 5740
# Using parallel, time passed was: 	 1.415118
# -0.26109869248375617
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 5364
# Using parallel, time passed was: 	 1.386896
# -0.008057622814703791
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 5041
# Using parallel, time passed was: 	 1.380621
# 0.47488216318197374
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 4758
# Using parallel, time passed was: 	 1.384774
# 0.4304832517182149
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 4487
# Using parallel, time passed was: 	 1.344390
# 0.3608020930641942
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 4260
# Using parallel, time passed was: 	 1.336287
# 0.38064145197495236
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 4017
# Using parallel, time passed was: 	 1.337244
# 0.9267130633161287
# [ True  True  True ...  True  True  True]
# 2861
# Number of Sources:	 2861
# Number of Events:	 3783
# Process ForkPoolWorker-1525:
# Process ForkPoolWorker-1528:
# Process ForkPoolWorker-1526:
# Process ForkPoolWorker-1522:
# Process ForkPoolWorker-1527:
# Process ForkPoolWorker-1524:
# Process ForkPoolWorker-1529:
# Process ForkPoolWorker-1523:
# Process ForkPoolWorker-1530:
# Process ForkPoolWorker-1521:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Using parallel, time passed was: 	 1.340872
# 1.4966294969308365
# [ True  True  True ...  True  True  True]
# 2861
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-febd02f4e571> in <module>()
#     168                                                                                          weights_type=weights_type,
#     169                                                                                          n_cpu=10,
# --> 170                                                                                          var_index_cut=var_cut_type)
#     171
#     172 #plots the energy cut vs max likilihood
#
# <ipython-input-4-febd02f4e571> in main(icecube_file_name, background_file_name, catalog_file_name, source_class_names, alpha, weights_type, n_cpu, var_index_cut)
#      75
#      76
# ---> 77         class_search.load_4lac(catalog_file_name, source_class_names, weights_type)
#      78
#      79         if(var_index_cut is not None):
#
# /home/kmcd23/Desktop/all_sky_folder/A0_programs/IceCubeAnalysis3.ipynb in load_4lac(self, catalog_file_name, source_class_names, weights_type)
#
# /home/kmcd23/Desktop/all_sky_folder/A0_programs/IceCubeAnalysis3.ipynb in load_catalog(self, catalog_file_name, source_class_names)
#
# /home/kmcd23/Desktop/all_sky_folder/A0_programs/IceCubeAnalysis3.ipynb in <listcomp>(.0)
#
# /home/kmcd23/Desktop/all_sky_folder/A0_programs/IceCubeAnalysis3.ipynb in luminosity_distance_from_redshift(self, z)
#
# /software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     350     if weight is None:
#     351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 352                        points)
#     353     else:
#     354         if points is not None:
#
# /software/python-anaconda-2020.02-el7-x86_64/lib/python3.7/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# /home/kmcd23/Desktop/all_sky_folder/A0_programs/IceCubeAnalysis3.ipynb in <lambda>(zp)
#
# KeyboardInterrupt:
